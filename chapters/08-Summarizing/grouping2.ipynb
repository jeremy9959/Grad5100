# %%
import penguins_setup as setup
import pandas as  pd
import numpy as np

# %%
simplified  = setup.setup_penguins(setup.penguins)

# %%
simplified
# Out:
#        species     island  ... flipper_length_std  body_mass_std
# 0       adelie  torgersen  ...          -0.563317      -0.563317
# 1       adelie  torgersen  ...          -0.500969      -0.500969
# 2       adelie  torgersen  ...          -1.186793      -1.186793
# 4       adelie  torgersen  ...          -0.937403      -0.937403
# 5       adelie  torgersen  ...          -0.688012      -0.688012
# ..         ...        ...  ...                ...            ...
# 339  chinstrap      dream  ...          -0.251578      -0.251578
# 340  chinstrap      dream  ...          -0.999750      -0.999750
# 341  chinstrap      dream  ...          -0.532143      -0.532143
# 342  chinstrap      dream  ...          -0.126883      -0.126883
# 343  chinstrap      dream  ...          -0.532143      -0.532143
#
# [333 rows x 11 columns]
